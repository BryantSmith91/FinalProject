# %%
# !git clone https://github.com/BryantSmith91/MoreFinalData.git
# Out:
# The system cannot find the path specified.
# fatal: destination path 'MoreFinalData' already exists and is not an empty directory.

# %%
import matplotlib.pyplot as plt
import socket
import glob
import os
import numpy as np
import tensorflow as tf
import imageio
# import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
from skimage.filters import threshold_otsu
from sklearn.preprocessing import MinMaxScaler
import numpy as np
from glob import glob
import scipy.misc
from matplotlib.patches import Circle,Ellipse
from matplotlib.patches import Rectangle
import os
from PIL import Image
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg19 import (
    VGG19, 
    preprocess_input, 
    decode_predictions
)
import keras
from matplotlib import pyplot as plt
import numpy as np
import gzip
# %matplotlib inline
from keras.layers import Input,Conv2D,MaxPooling2D,UpSampling2D,concatenate,Conv2DTranspose
from keras.models import Model
from keras.optimizers import RMSprop
from keras.layers.normalization import BatchNormalization
from tensorflow.keras.preprocessing import image

# %%
from glob import glob
data = glob('MoreFinalData/*')
len(data)
# Out:
# 6000

# %%
import skimage
from tensorflow.keras.preprocessing import image

matrix = []
array = []

for x in range(0, len(data)):
    image_size =(224,224)
    im = image.load_img(data[x], target_size=image_size, color_mode='grayscale')
    matrix.append(im)
    array.append(skimage.img_as_float(matrix[x]))
imagearray = np.asarray(array)

# %%
# Out:
#   File "<ipython-input-31-1527323af517>", line 1
#     data[]
#          ^
# SyntaxError: invalid syntax

# %%
imagearray = imagearray.reshape(-1, 224,224, 1)

# %%
# 

batch_size = 52
epochs = 50
inChannel = 1
x, y = 224, 224
input_img= Input(shape=(x,y,inChannel))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0818 13:50:14.733430  9892 deprecation_wrapper.py:119] From C:\Users\bryan\Miniconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0818 13:50:14.755901  9892 deprecation_wrapper.py:119] From C:\Users\bryan\Miniconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.

# %%
from sklearn.model_selection import train_test_split


train_X, real_X, train_ground, real_ground = train_test_split(imagearray, imagearray, 
                                                    test_size=0.2,
                                                    random_state=13)

# %%
real_X.shape
train_X.shape
# Out:
# (4800, 224, 224, 1)

# %%
# 

def autoencoder(input_img):
    #encoder
    #input = 28 x 28 x 1 (wide and thin)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(input_img) #28 x 28 x 32
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1) #14 x 14 x 32
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1) #14 x 14 x 64
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2) #7 x 7 x 64
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2) #7 x 7 x 128 (small and thick)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3) #7 x 7 x 64
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3) #7 x 7 x 256
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
#     conv6 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)
    
    #decoder
    
    conv6 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)
    up1 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv6), conv4], axis=3)
    conv7 = Conv2D(256, (3, 3), activation='relu', padding='same')(up1)
    up2 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv7), conv3], axis=3)
    conv8 = Conv2D(128, (3, 3), activation='relu', padding='same')(up2)
    up3 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv8), conv2], axis=3)
    conv9 = Conv2D(64, (3, 3), activation='relu', padding='same')(up3)
    up4 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv9), conv1], axis=3)
    conv10 = Conv2D(32, (3, 3), activation='relu', padding='same')(up4)
    decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(conv10)
    return decoded
#     conv7 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6) #7 x 7 x 128
#     up1 = UpSampling2D((2,2))(conv4) # 14 x 14 x 128
#     conv5 = Conv2D(64, (3, 3), activation='relu', padding='same')(up1) # 14 x 14 x 64
#     up2 = UpSampling2D((2,2))(conv5) # 28 x 28 x 64
#     decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(up2) # 28 x 28 x 1
#     return decoded

# %%
# 

autoencoder = Model(input_img, autoencoder(input_img))
autoencoder.compile(loss='mean_squared_error', optimizer = RMSprop())
# Out:
# W0818 10:13:35.575642 13476 deprecation_wrapper.py:119] From C:\Users\bryan\Miniconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
autoencoder.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 1)  0
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 224, 224, 32) 320         input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_33 (MaxPooling2D) (None, 112, 112, 32) 0           conv2d_59[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 112, 112, 64) 18496       max_pooling2d_33[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_34 (MaxPooling2D) (None, 56, 56, 64)   0           conv2d_60[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 56, 56, 128)  73856       max_pooling2d_34[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_35 (MaxPooling2D) (None, 28, 28, 128)  0           conv2d_61[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 28, 28, 256)  295168      max_pooling2d_35[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_36 (MaxPooling2D) (None, 14, 14, 256)  0           conv2d_62[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 14, 14, 512)  1180160     max_pooling2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 14, 14, 512)  2359808     conv2d_63[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_12 (Conv2DTran (None, 28, 28, 256)  524544      conv2d_64[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 28, 28, 512)  0           conv2d_transpose_12[0][0]
#                                                                  conv2d_62[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 28, 28, 256)  1179904     concatenate_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_13 (Conv2DTran (None, 56, 56, 128)  131200      conv2d_65[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 56, 56, 256)  0           conv2d_transpose_13[0][0]
#                                                                  conv2d_61[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 56, 56, 128)  295040      concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_14 (Conv2DTran (None, 112, 112, 64) 32832       conv2d_66[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 112, 112, 128 0           conv2d_transpose_14[0][0]
#                                                                  conv2d_60[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 112, 112, 64) 73792       concatenate_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_15 (Conv2DTran (None, 224, 224, 32) 8224        conv2d_67[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 224, 224, 64) 0           conv2d_transpose_15[0][0]
#                                                                  conv2d_59[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 224, 224, 32) 18464       concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 224, 224, 1)  289         conv2d_68[0][0]
# ==================================================================================================
# Total params: 6,192,097
# Trainable params: 6,192,097
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# 

autoencoder_train = autoencoder.fit(train_X, train_ground,batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(real_X, real_ground))

# for x in range(len(train_X)):
# Out:
# W0818 10:13:45.296922 13476 deprecation_wrapper.py:119] From C:\Users\bryan\Miniconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W0818 10:13:45.301411 13476 deprecation_wrapper.py:119] From C:\Users\bryan\Miniconda3\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# Train on 4800 samples, validate on 1200 samples
# Epoch 1/50
# 4800/4800 [==============================] - 57s 12ms/step - loss: 0.0638 - val_loss: 0.0048
# Epoch 2/50
# 4800/4800 [==============================] - 48s 10ms/step - loss: 0.0047 - val_loss: 0.0034
# Epoch 3/50
# 4800/4800 [==============================] - 47s 10ms/step - loss: 0.0030 - val_loss: 0.0019
# Epoch 4/50
# 4800/4800 [==============================] - 47s 10ms/step - loss: 0.0034 - val_loss: 0.0014
# Epoch 5/50
# 4800/4800 [==============================] - 48s 10ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 6/50
# 4800/4800 [==============================] - 48s 10ms/step - loss: 0.0017 - val_loss: 9.3703e-04
# Epoch 7/50
# 4800/4800 [==============================] - 47s 10ms/step - loss: 0.0016 - val_loss: 0.0011
# Epoch 8/50
# 4800/4800 [==============================] - 47s 10ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 9/50
# 4800/4800 [==============================] - 48s 10ms/step - loss: 0.0013 - val_loss: 8.4553e-04
# Epoch 10/50
# 4800/4800 [==============================] - 49s 10ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 11/50
# 4800/4800 [==============================] - 48s 10ms/step - loss: 9.8559e-04 - val_loss: 7.9247e-04
# Epoch 12/50
# 4800/4800 [==============================] - 49s 10ms/step - loss: 9.2404e-04 - val_loss: 6.0459e-04
# Epoch 13/50
# 4800/4800 [==============================] - 48s 10ms/step - loss: 8.2851e-04 - val_loss: 6.5888e-04
# Epoch 14/50
# 4800/4800 [==============================] - 48s 10ms/step - loss: 7.8435e-04 - val_loss: 3.4924e-04
# Epoch 15/50
# 4800/4800 [==============================] - 48s 10ms/step - loss: 7.0653e-04 - val_loss: 4.7183e-04
# Epoch 16/50
# 4800/4800 [==============================] - 48s 10ms/step - loss: 6.8099e-04 - val_loss: 5.0294e-04
# Epoch 17/50
# 4800/4800 [==============================] - 47s 10ms/step - loss: 6.4734e-04 - val_loss: 4.9878e-04
# Epoch 18/50
# 4800/4800 [==============================] - 47s 10ms/step - loss: 5.8530e-04 - val_loss: 7.1014e-04
# Epoch 19/50
# 4800/4800 [==============================] - 47s 10ms/step - loss: 5.4961e-04 - val_loss: 2.2777e-04
# Epoch 20/50
# 4800/4800 [==============================] - 47s 10ms/step - loss: 4.9723e-04 - val_loss: 2.2462e-04
# Epoch 21/50
# 4800/4800 [==============================] - 47s 10ms/step - loss: 4.8341e-04 - val_loss: 6.5137e-04
# Epoch 22/50
# 4800/4800 [==============================] - 47s 10ms/step - loss: 4.5149e-04 - val_loss: 5.1044e-04
# Epoch 23/50
# 4800/4800 [==============================] - 47s 10ms/step - loss: 4.4848e-04 - val_loss: 4.5412e-04
# Epoch 24/50
# 4800/4800 [==============================] - 47s 10ms/step - loss: 4.0199e-04 - val_loss: 1.6238e-04
# Epoch 25/50
# 4800/4800 [==============================] - 48s 10ms/step - loss: 4.0097e-04 - val_loss: 4.4459e-04
# Epoch 26/50
# 4800/4800 [==============================] - 47s 10ms/step - loss: 3.7513e-04 - val_loss: 2.9263e-04
# Epoch 27/50
# 4800/4800 [==============================] - 47s 10ms/step - loss: 3.5580e-04 - val_loss: 5.0506e-04
# Epoch 28/50
# 4800/4800 [==============================] - 47s 10ms/step - loss: 3.4244e-04 - val_loss: 4.1445e-04
# Epoch 29/50
# 4800/4800 [==============================] - 48s 10ms/step - loss: 3.3294e-04 - val_loss: 1.2826e-04
# Epoch 30/50
# 4800/4800 [==============================] - 47s 10ms/step - loss: 3.1068e-04 - val_loss: 2.4500e-04
# Epoch 31/50
# 4800/4800 [==============================] - 47s 10ms/step - loss: 3.0663e-04 - val_loss: 2.0716e-04
# Epoch 32/50
# 4800/4800 [==============================] - 47s 10ms/step - loss: 3.0588e-04 - val_loss: 1.6771e-04
# Epoch 33/50
# 4800/4800 [==============================] - 47s 10ms/step - loss: 2.7466e-04 - val_loss: 1.7289e-04
# Epoch 34/50
# 4800/4800 [==============================] - 49s 10ms/step - loss: 2.9464e-04 - val_loss: 1.4111e-04
# Epoch 35/50
# 4800/4800 [==============================] - 49s 10ms/step - loss: 2.7604e-04 - val_loss: 3.5985e-04
# Epoch 36/50
# 4800/4800 [==============================] - 47s 10ms/step - loss: 2.6864e-04 - val_loss: 1.5117e-04
# Epoch 37/50
# 4800/4800 [==============================] - 67s 14ms/step - loss: 2.5098e-04 - val_loss: 1.6550e-04
# Epoch 38/50
# 4800/4800 [==============================] - 53s 11ms/step - loss: 2.4300e-04 - val_loss: 1.7147e-04
# Epoch 39/50
# 4800/4800 [==============================] - 48s 10ms/step - loss: 2.3725e-04 - val_loss: 1.0187e-04
# Epoch 40/50
# 4800/4800 [==============================] - 47s 10ms/step - loss: 2.6700e-04 - val_loss: 1.4846e-04
# Epoch 41/50
# 4800/4800 [==============================] - 48s 10ms/step - loss: 2.5385e-04 - val_loss: 1.2013e-04
# Epoch 42/50
# 4800/4800 [==============================] - 48s 10ms/step - loss: 2.1695e-04 - val_loss: 4.1683e-04
# Epoch 43/50
# 4800/4800 [==============================] - 48s 10ms/step - loss: 2.2768e-04 - val_loss: 1.6880e-04
# Epoch 44/50
# 4800/4800 [==============================] - 49s 10ms/step - loss: 2.2228e-04 - val_loss: 2.1022e-04
# Epoch 45/50
# 4800/4800 [==============================] - 48s 10ms/step - loss: 2.0957e-04 - val_loss: 1.9617e-04
# Epoch 46/50
# 4800/4800 [==============================] - 48s 10ms/step - loss: 2.0579e-04 - val_loss: 1.4632e-04
# Epoch 47/50
# 4800/4800 [==============================] - 48s 10ms/step - loss: 2.0338e-04 - val_loss: 1.9609e-04
# Epoch 48/50
# 4800/4800 [==============================] - 48s 10ms/step - loss: 1.8608e-04 - val_loss: 1.8726e-04
# Epoch 49/50
# 4800/4800 [==============================] - 48s 10ms/step - loss: 2.0602e-04 - val_loss: 1.3747e-04
# Epoch 50/50
# 4800/4800 [==============================] - 48s 10ms/step - loss: 1.7990e-04 - val_loss: 1.0800e-04

# %%
# 50 batch size -- too small

loss = autoencoder_train.history['loss']
val_loss = autoencoder_train.history['val_loss']
epochs = range(15)
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
#136 batch size -- too big
loss = autoencoder_train.history['loss']
val_loss = autoencoder_train.history['val_loss']
epochs = range(15)
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
#115 batch size - 

loss = autoencoder_train.history['loss']
val_loss = autoencoder_train.history['val_loss']
epochs = range(15)
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
#256 batch size?? - 512 breaks it

loss = autoencoder_train.history['loss']
val_loss = autoencoder_train.history['val_loss']
epochs = range(15)
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
#128 batch size + 50 epoch
loss = autoencoder_train.history['loss']
val_loss = autoencoder_train.history['val_loss']
epochs = range(50)
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
autoencoder.save('128batch50epoch.h5')

# %%
autoencoder.save_weights('firstgpurun.h5')

# %%
autoencoder.load_weights('128batch10epochweights.h5')

# %%
autoencoder.compile(loss='mean_squared_error',optimizer=RMSprop())

# %%
pred = autoencoder.predict(real_X)

# %%
plt.figure(figsize=(20,4))
for i in range(5):
    plt.subplot(1,5,i+1)
    plt.imshow(real_ground[i,...,0],cmap='gray')
plt.show()
plt.figure(figsize=(20,4))
for i in range(5):
    plt.subplot(1,5,i+1)
    plt.imshow(pred[i,...,0],cmap='gray')
plt.show()

# %%
#maybe not massively overfitting this time?
loss = autoencoder_train.history['loss']
val_loss = autoencoder_train.history['val_loss']
epochs = range(10)
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,4))
for i in range(5):
    plt.subplot(1,5,i+1)
    plt.imshow(real_ground[i,...,0],cmap='gray')
plt.show()
plt.figure(figsize=(20,4))
for i in range(5):
    plt.subplot(1,5,i+1)
    plt.imshow(pred[i,...,0],cmap='gray')
plt.show()

# %%
# altered = glob('Altered/Altered-Hard/*')
altered = glob('smallaltered/*')
print(f"{len(data)} is the training data and {len(altered)} is the test data.")
# Out:
# 6000 is the training data and 129 is the test data.

# %%
# altered = glob('Altered/Altered-Hard/*')
# # altered = glob('smallaltered/*')
# print(f"{len(data)} is the training data and {len(altered)} is the test data.")
altmat = []
altarr = []

for x in range(0, len(altered)):
    image_size =(224,224)
    ima = image.load_img(altered[x], target_size=image_size, color_mode='grayscale')
    altmat.append(ima)
    altarr.append(skimage.img_as_float(altmat[x]))
alteredarray = np.asarray(altarr)
alteredarray = alteredarray.reshape(-1, 224,224, 1)

# %%
# alteredarray[1]
pred = autoencoder.predict(alteredarray)

# %%
plt.figure(figsize=(20,4))
for i in range(5):
    plt.subplot(1,5,i+1)
    plt.imshow(imagearray[i,...,0],cmap='gray')
plt.show()
plt.figure(figsize=(20,4))
for i in range(5):
    plt.subplot(1,5,i+1)
    plt.imshow(pred[i,...,0],cmap='gray')
plt.show()

# %%
plt.figure(figsize=(20,4))
for i in range(5):
    plt.subplot(1,5,i+1)
    plt.imshow(real_ground[i,...,0],cmap='gray')
plt.show()
plt.figure(figsize=(20,4))
for i in range(5):
    plt.subplot(1,5,i+1)
    plt.imshow(real_ground[i,...,0],cmap='gray')
plt.show()

# %%
loss = autoencoder_train.history['loss']
val_loss = autoencoder_train.history['val_loss']
epochs = range(10)
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
loss = autoencoder_train.history['loss']
val_loss = autoencoder_train.history['val_loss']
epochs = range(50)
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,4))
for i in range(5):
    plt.subplot(1,5,i+1)
    plt.imshow(real_ground[i,...,0],cmap='gray')
plt.show()
plt.figure(figsize=(20,4))
for i in range(5):
    plt.subplot(1,5,i+1)
    plt.imshow(pred[i,...,0],cmap='gray')
plt.show()

# %%
loss = autoencoder_train.history['loss']
val_loss = autoencoder_train.history['val_loss']
epochs = range(50)
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,4))
for i in range(5):
    plt.subplot(1,5,i+1)
    plt.imshow(real_ground[i,...,0],cmap='gray')
plt.show()
plt.figure(figsize=(20,4))
for i in range(5):
    plt.subplot(1,5,i+1)
    plt.imshow(pred[i,...,0],cmap='gray')
plt.show()

# %%
plt.figure(figsize=(20,4))
for i in range(5):
    plt.subplot(1,5,i+1)
    plt.imshow(real_ground[i,...,0],cmap='gray')
plt.show()
plt.figure(figsize=(20,4))
for i in range(5):
    plt.subplot(1,5,i+1)
    plt.imshow(pred[i,...,0],cmap='gray')
plt.show()

# %%
# altered = glob('Altered/Altered-Hard/*')
altered = glob('smallaltered/*')
print(f"{len(data)} is the training data and {len(altered)} is the test data.")
altmat = []
altarr = []

for x in range(0, len(altered)):
    image_size =(224,224)
    ima = image.load_img(altered[x], target_size=image_size, color_mode='grayscale')
    altmat.append(ima)
    altarr.append(skimage.img_as_float(altmat[x]))
alteredarray = np.asarray(altarr)
alteredarray = alteredarray.reshape(-1, 224,224, 1)
# Out:
# 6000 is the training data and 129 is the test data.

# %%
from sklearn.model_selection import train_test_split


alt_x, realalt_x, alt_ground, alt_real = train_test_split(alteredarray, alteredarray, 
                                                    test_size=0.2,
                                                    random_state=13)

# %%
# 

batch_size = 52
epochs = 50
inChannel = 1
x, y = 224, 224
input_img= Input(shape=(x,y,inChannel))

# %%
autoencoder_train = autoencoder.fit(alt_x, alt_ground,batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(realalt_x, alt_real))
# Out:
# Train on 103 samples, validate on 26 samples
# Epoch 1/50
# 103/103 [==============================] - 12s 115ms/step - loss: 1.2464e-04 - val_loss: 2.7409e-04
# Epoch 2/50
# 103/103 [==============================] - 1s 10ms/step - loss: 6.6495e-04 - val_loss: 0.0013
# Epoch 3/50
# 103/103 [==============================] - 1s 10ms/step - loss: 8.0663e-04 - val_loss: 9.8348e-05
# Epoch 4/50
# 103/103 [==============================] - 1s 10ms/step - loss: 7.8226e-05 - val_loss: 5.5328e-05
# Epoch 5/50
# 103/103 [==============================] - 1s 10ms/step - loss: 5.1682e-05 - val_loss: 5.1101e-05
# Epoch 6/50
# 103/103 [==============================] - 1s 10ms/step - loss: 4.8575e-05 - val_loss: 4.9905e-05
# Epoch 7/50
# 103/103 [==============================] - 1s 10ms/step - loss: 4.7757e-05 - val_loss: 5.0978e-05
# Epoch 8/50
# 103/103 [==============================] - 1s 10ms/step - loss: 5.0975e-05 - val_loss: 6.6315e-05
# Epoch 9/50
# 103/103 [==============================] - 1s 10ms/step - loss: 7.4625e-05 - val_loss: 1.6001e-04
# Epoch 10/50
# 103/103 [==============================] - 1s 10ms/step - loss: 2.1123e-04 - val_loss: 3.8812e-04
# Epoch 11/50
# 103/103 [==============================] - 1s 10ms/step - loss: 3.6345e-04 - val_loss: 4.5315e-04
# Epoch 12/50
# 103/103 [==============================] - 1s 10ms/step - loss: 3.7449e-04 - val_loss: 2.4010e-04
# Epoch 13/50
# 103/103 [==============================] - 1s 10ms/step - loss: 1.8345e-04 - val_loss: 1.5122e-04
# Epoch 14/50
# 103/103 [==============================] - 1s 10ms/step - loss: 1.1837e-04 - val_loss: 1.1606e-04
# Epoch 15/50
# 103/103 [==============================] - 1s 10ms/step - loss: 1.0929e-04 - val_loss: 1.0324e-04
# Epoch 16/50
# 103/103 [==============================] - 1s 10ms/step - loss: 9.2699e-05 - val_loss: 9.7939e-05
# Epoch 17/50
# 103/103 [==============================] - 1s 10ms/step - loss: 1.1141e-04 - val_loss: 1.8063e-04
# Epoch 18/50
# 103/103 [==============================] - 1s 10ms/step - loss: 2.0361e-04 - val_loss: 3.8604e-04
# Epoch 19/50
# 103/103 [==============================] - 1s 10ms/step - loss: 3.3756e-04 - val_loss: 3.2449e-04
# Epoch 20/50
# 103/103 [==============================] - 1s 10ms/step - loss: 3.3548e-04 - val_loss: 3.1552e-04
# Epoch 21/50
# 103/103 [==============================] - 1s 10ms/step - loss: 2.5114e-04 - val_loss: 1.6767e-04
# Epoch 22/50
# 103/103 [==============================] - 1s 10ms/step - loss: 1.5983e-04 - val_loss: 2.1809e-04
# Epoch 23/50
# 103/103 [==============================] - 1s 10ms/step - loss: 1.8406e-04 - val_loss: 1.6918e-04
# Epoch 24/50
# 103/103 [==============================] - 1s 10ms/step - loss: 1.4943e-04 - val_loss: 1.3960e-04
# Epoch 25/50
# 103/103 [==============================] - 1s 10ms/step - loss: 1.3357e-04 - val_loss: 1.8227e-04
# Epoch 26/50
# 103/103 [==============================] - 1s 10ms/step - loss: 2.0182e-04 - val_loss: 1.6524e-04
# Epoch 27/50
# 103/103 [==============================] - 1s 10ms/step - loss: 1.3558e-04 - val_loss: 8.8217e-05
# Epoch 28/50
# 103/103 [==============================] - 1s 10ms/step - loss: 7.8154e-05 - val_loss: 7.3317e-05
# Epoch 29/50
# 103/103 [==============================] - 1s 10ms/step - loss: 9.4476e-05 - val_loss: 3.5600e-04
# Epoch 30/50
# 103/103 [==============================] - 1s 10ms/step - loss: 5.1861e-04 - val_loss: 7.1277e-04
# Epoch 31/50
# 103/103 [==============================] - 1s 10ms/step - loss: 4.7792e-04 - val_loss: 2.0863e-04
# Epoch 32/50
# 103/103 [==============================] - 1s 10ms/step - loss: 2.3162e-04 - val_loss: 1.3619e-04
# Epoch 33/50
# 103/103 [==============================] - 1s 10ms/step - loss: 1.1649e-04 - val_loss: 9.6691e-05
# Epoch 34/50
# 103/103 [==============================] - 1s 10ms/step - loss: 9.0695e-05 - val_loss: 9.4054e-05
# Epoch 35/50
# 103/103 [==============================] - 1s 10ms/step - loss: 9.2522e-05 - val_loss: 1.2513e-04
# Epoch 36/50
# 103/103 [==============================] - 1s 10ms/step - loss: 1.3491e-04 - val_loss: 2.4658e-04
# Epoch 37/50
# 103/103 [==============================] - 1s 10ms/step - loss: 2.5745e-04 - val_loss: 3.2615e-04
# Epoch 38/50
# 103/103 [==============================] - 1s 10ms/step - loss: 2.7597e-04 - val_loss: 1.9568e-04
# Epoch 39/50
# 103/103 [==============================] - 1s 10ms/step - loss: 1.7617e-04 - val_loss: 1.3807e-04
# Epoch 40/50
# 103/103 [==============================] - 1s 10ms/step - loss: 1.2405e-04 - val_loss: 9.8164e-05
# Epoch 41/50
# 103/103 [==============================] - 1s 10ms/step - loss: 9.4213e-05 - val_loss: 1.1233e-04
# Epoch 42/50
# 103/103 [==============================] - 1s 10ms/step - loss: 1.2016e-04 - val_loss: 1.8975e-04
# Epoch 43/50
# 103/103 [==============================] - 1s 10ms/step - loss: 1.8186e-04 - val_loss: 2.2694e-04
# Epoch 44/50
# 103/103 [==============================] - 1s 10ms/step - loss: 1.9780e-04 - val_loss: 2.0430e-04
# Epoch 45/50
# 103/103 [==============================] - 1s 10ms/step - loss: 2.4486e-04 - val_loss: 4.2708e-04
# Epoch 46/50
# 103/103 [==============================] - 1s 10ms/step - loss: 3.5710e-04 - val_loss: 2.4880e-04
# Epoch 47/50
# 103/103 [==============================] - 1s 10ms/step - loss: 2.1712e-04 - val_loss: 2.4119e-04
# Epoch 48/50
# 103/103 [==============================] - 1s 10ms/step - loss: 2.2787e-04 - val_loss: 2.8850e-04
# Epoch 49/50
# 103/103 [==============================] - 1s 10ms/step - loss: 2.1511e-04 - val_loss: 1.2602e-04
# Epoch 50/50
# 103/103 [==============================] - 1s 10ms/step - loss: 1.1116e-04 - val_loss: 9.5448e-05

# %%
loss = autoencoder_train.history['loss']
val_loss = autoencoder_train.history['val_loss']
epochs = range(50)
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,4))
for i in range(5):
    plt.subplot(1,5,i+1)
    plt.imshow(real_ground[i,...,0],cmap='gray')
plt.show()
plt.figure(figsize=(20,4))
for i in range(5):
    plt.subplot(1,5,i+1)
    plt.imshow(pred[i,...,0],cmap='gray')
plt.show()

# %%
bb

# %%
def make_generator_model():
    model = tf.keras.Sequential()
    model.add(layers.Dense(7*7*256, use_bias=False, input_shape=(100,)))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Reshape((7, 7, 256)))
    assert model.output_shape == (None, 7, 7, 256) # Note: None is the batch size

    model.add(layers.Conv2DTranspose(128, (5, 5), strides=(1, 1), padding='same', use_bias=False))
    assert model.output_shape == (None, 7, 7, 128)
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Conv2DTranspose(64, (5, 5), strides=(2, 2), padding='same', use_bias=False))
    assert model.output_shape == (None, 14, 14, 64)
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Conv2DTranspose(1, (5, 5), strides=(2, 2), padding='same', use_bias=False, activation='tanh'))
    assert model.output_shape == (None, 28, 28, 1)

    return model

# %%
generator = make_generator_model()

noise = tf.random.normal([1, 100])
generated_image = generator(noise, training=False)
plt.imshow(generated_image[0, :, :, 0], cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-5c839cc61fad> in <module>
#       3 noise = tf.random.normal([1, 100])
#       4 generated_image = generator(noise, training=False)
# ----> 5 plt.imshow(generated_image[0, :, :, 0], cmap='gray')
#
# ~\Miniconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2699         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2700         resample=resample, url=url, **({"data": data} if data is not
# -> 2701         None else {}), **kwargs)
#    2702     sci(__ret)
#    2703     return __ret
#
# ~\Miniconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~\Miniconda3\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5492                               resample=resample, **kwargs)
#    5493
# -> 5494         im.set_data(X)
#    5495         im.set_alpha(alpha)
#    5496         if im.get_clip_path() is None:
#
# ~\Miniconda3\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     640         if (self._A.dtype != np.uint8 and
#     641                 not np.can_cast(self._A.dtype, float, "same_kind")):
# --> 642             raise TypeError("Image data cannot be converted to float")
#     643
#     644         if not (self._A.ndim == 2
#
# TypeError: Image data cannot be converted to float
